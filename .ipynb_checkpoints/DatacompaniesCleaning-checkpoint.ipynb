# %%
import pandas as pd
import re
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %%
at_least_1_office = db.companies.find({"offices":{"$not":{"$size":0}}})

# %%
df = pd.DataFrame(at_least_1_office)

# %%
def getFirst(data):

    data = data['offices']

    principal = None

    if data[0]['latitude'] and data[0]['longitude']:

        principal = {

            "type":"Point",

            "coordinates":[data[0]['longitude'], data[0]['latitude']]

        }

    return {

        "totalOffices": len(data),

        "lat": data[0]['latitude'],

        "lng": data[0]['longitude'],

        "oficina_principal": principal

    }

Geoloc = df[["offices"]].apply(getFirst, result_type="expand", axis=1)

# %% [raw]
# def get(d):
#     d = d['offices']
#
#     for i in d:
#         if i['latitude'] and i['longitude']:
#             return {"lat": d[0]['latitude'], "lng": d[0]['longitude']}
#
#
# Geoloc = df[["offices"]].apply(get, result_type="expand", axis=1)

# %%
df.drop(['_id', 'acquisition','created_at', 'crunchbase_url', 'ipo', 'homepage_url', 'image', 'partners', 'providerships', 'updated_at',  'permalink', 'products', 'external_links', 'acquisitions', 'alias_list', 'blog_feed_url', 'blog_url', 'category_code', 'deadpooled_day', 'deadpooled_month', 'deadpooled_url', 'deadpooled_year', 'email_address', 'founded_day', 'founded_month', 'phone_number', 'screenshots', 'tag_list', 'twitter_username', 'video_embeds', 'relationships', 'milestones', 'investments', 'overview', 'funding_rounds', 'competitions'] , axis=1, inplace=True)

# %%
df= df[['description', 'founded_year', 'name', 'total_money_raised', 'number_of_employees']].fillna('Unknown')

# %%
DataBase = pd.concat([df, Geoloc], axis=1)

# %%
def showmedamoney (m):
    
    m=str(m)
    
    floatmoney = float((re.findall('\d+|\d+.?\d+', m))[0])
    
    if m.startswith('C$'):x = floatmoney*1.31
    elif m.startswith('€'):x = floatmoney*0.89
    elif m.startswith('$'):x = floatmoney
    elif m.startswith('£'):x = floatmoney*0.80
    elif m.startswith('¥'):x = floatmoney*108.96
    else:
        x=floatmoney
        
    if m.endswith('M'):
        x = x*1000000
        return x
    elif m.endswith('B'):
        x = x*1000000000
        return x
    elif m.endswith('k'):
        x = x*1000
        return x
    else:
        return x

# %%
DataBase['total_money_raised']= DataBase['total_money_raised'].apply(showmedamoney)

# %%
def activity (m):
    m = str(m)
    
    if re.search("s*(design)|(Design)\s*", m):
        return m
    elif re.search("s*(Video)|(video)\s*", m):
        return m
    elif re.search("s*(Game)|(game)\s*", m):
        return m
    elif re.search("s*(Gaming)|(gaming)\s*", m):
        return m
    
    else:
        return 'OTHERS'

# %%
DataBase['description']= DataBase['description'].apply(activity)

# %%
DataBase=DataBase[DataBase['description']!='OTHERS']

# %%
DataBase['total_money_raised'] = DataBase['total_money_raised'].fillna(0.0).astype(int)

# %%
DataBase.to_json('/home/javier/Documentos/visualizing-real-world-data-project/DataBase_py_clean1.json', orient='records')

# %%
DataBase
# Out:
#                                     description founded_year  \
# 40               Online & Mobile Video Platform         2006
# 46                Awesome Photo & Video Sharing         2002
# 50                         Online video sharing         2005
# 54                  Live Social Video Community         2007
# 78                         comedy video website         2007
# 100                       Video sharing service         2005
# 103                       Social Gaming Company         2005
# 118                      Video guide for hotels         2007
# 150                   Video Processing Software         2005
# 189                   video advertising network         2005
# 205                  Online games media company         2006
# 208                Online social learning games         2006
# 209                   Digital video ad platform         2005
# 249                       Online video platform         2004
# 276                           Hosted Video Chat         2001
# 301                   User Generated Video Site         2004
# 303                  Online Video Entertainment         2003
# 323           Web video communications platform         2007
# 332                       Gaming social network         2006
# 334                         Dance Video sharing         2007
# 342                    Video Preview Technology         2007
# 343                       Video Tagging Service      Unknown
# 348           Video search and recommendations.         2006
# 350                video distribution solutions         2008
# 379     Independent Video Entertainment Network         2004
# 410                    Video Ad Buying Platform         2006
# 433    Largest mobile games community in N Amer         2005
# 460     Music, Videos, Games for Mobile Devices         2004
# 464            Social Gaming Portal & Platform          2002
# 486               Free online multiplayer game          2006
# ...                                         ...          ...
# 12974                Interactive video web tool         2008
# 12989                    Game Developer Company         2008
# 13009                     Graphic Design Studio      Unknown
# 13015                 Video Synopsis technology         2007
# 13071                        IC Design Software         1996
# 13118                      B2B Game Distributor         1990
# 13121                 Game Console Manufacturer         2003
# 13138                     Casual Game Developer         2000
# 13139                            Game Developer         1997
# 13153              Online Graphic Design School         2008
# 13214                 Video Encoding Technology         2004
# 13215          sensor designer and manufacturer         1983
# 13229                   Video Platform Provider         2001
# 13250                     Online video service          2009
# 13336                        Software for games      Unknown
# 13342                      Solar system designs      Unknown
# 13355          Design Engineering/Manufacturing      Unknown
# 13367                      IC design solutions          2005
# 13371                           video solutions      Unknown
# 13409     Schafkopf Community (German Cardgame)         2007
# 13421                Web Design and Development         2009
# 13436                        Web Design Bangkok      Unknown
# 13474                   Game Development Studio      Unknown
# 13475                Digital video broadcasting      Unknown
# 13476       audio/visual design and integration      Unknown
# 13510      Multi-screen Player for Native Games         2008
# 13552                            Game Developer      Unknown
# 13554   Publisher and developer of mobile games         2006
# 13619                  Website Design, Shopsite         1999
# 13713               Web Development, Web Design         1998
#
#                                        name  total_money_raised  \
# 40                                     Kyte            23000000
# 46                                  SmugMug                   0
# 50                                  YouTube            11000000
# 54                                  Ustream            60000000
# 78                             Funny Or Die            18000000
# 100                             Dailymotion            68000000
# 103                                 RockYou           136000000
# 118                                  TVtrip            13000000
# 150                               MotionDSP                   0
# 189                               ScanScout            17000000
# 205                                   Curse            12000000
# 208                                 Grockit            44000000
# 209                               Kiptronic             7000000
# 249                              Brightcove           103000000
# 276                               Userplane                   0
# 301                                  Revver            12000000
# 303                                Metacafe            50000000
# 323                                  TokBox            26000000
# 332                              Kongregate            19000000
# 334                                DanceJam             4000000
# 342                                 SlapVid                   0
# 343                                  Veotag             1000000
# 348                           Digitalsmiths            31000000
# 350                             KIT digital            20000000
# 379                                   Mevio            48000000
# 410                               TubeMogul            53000000
# 433                               MocoSpace            10000000
# 460                               Thumbplay            41000000
# 464                                   Xfire             7000000
# 486                                  OMGPOP            16000000
# ...                                     ...                 ...
# 12974                              Spotcher                   0
# 12989                      Dystopia Studios                   0
# 13009                                Gotham                   0
# 13015                              BriefCam            14000000
# 13071                            SpringSoft                   0
# 13118                           CompuExpert                   0
# 13121                   Digital Interactive                   0
# 13138                          PopCap Games            22000000
# 13139                     Snowblind Studios                   0
# 13153             The Graphic Design School                   0
# 13214                             Haivision             5000000
# 13215                                  MEAS                   0
# 13229                  Bamboo Media Casting                   0
# 13250                                 SPOTI                   0
# 13336                          Midway Games                   0
# 13342  Greenland Hong Kong Holdings Limited            13000000
# 13355                           BreconRidge            61000000
# 13367                             Teklatech             8000000
# 13371                                Anevia             8000000
# 13409                              Sauspiel                   0
# 13421                       Collective Core                   0
# 13436                       Design Chemical                   0
# 13474                  California 7 Studios                   0
# 13475                              TrueSpan                   0
# 13476                Fox River Audio Visual                   0
# 13510                            Antix Labs             3000000
# 13552                           Shape Games                   0
# 13554                      G5 Entertainment                   0
# 13619           Top Rated Website Designers                   0
# 13713                           Atlantic BT                   0
#
#       number_of_employees        lat         lng  \
# 40                     40  37.788482 -122.409173
# 46                     62  37.390056 -122.067692
# 50                      0  37.627971 -122.426804
# 54                    250  37.392936 -122.079480
# 78                Unknown  37.421621 -122.137444
# 100                   120        NaN         NaN
# 103                   106  37.484619 -122.206893
# 118               Unknown  48.856667    2.350987
# 150                    25        NaN         NaN
# 189                    40  42.340889  -71.051931
# 205                    58  37.787092 -122.399972
# 208                    25  37.775196 -122.419204
# 209                    20  37.792394 -122.402349
# 249                   220  42.362993  -71.086596
# 276                    10  34.016760 -118.495566
# 301               Unknown  34.052187 -118.243425
# 303               Unknown  37.437328 -122.159928
# 323                    55  37.779507 -122.390710
# 332                    20  37.786942 -122.401245
# 334                     0  37.781557 -122.407959
# 342               Unknown  40.445009  -79.948563
# 343               Unknown  40.752957  -73.985460
# 348                    60        NaN         NaN
# 350                   200  40.751816  -73.971655
# 379               Unknown  37.782263 -122.392142
# 410                   230  37.836957 -122.286493
# 433                    25  42.350274  -71.058768
# 460                    70  40.725435  -73.997395
# 464               Unknown  34.018466 -118.498630
# 486                    50  40.723384  -74.001704
# ...                   ...        ...         ...
# 12974             Unknown  34.061711 -118.401705
# 12989                   2        NaN         NaN
# 13009             Unknown        NaN         NaN
# 13015                  30        NaN         NaN
# 13071                 400  37.370270 -121.924053
# 13118             Unknown  33.673492 -117.668684
# 13121             Unknown  33.766701 -118.197677
# 13138             Unknown  47.616169 -122.345190
# 13139             Unknown  47.770550 -122.186198
# 13153                   8  34.087825 -118.379493
# 13214             Unknown        NaN         NaN
# 13215             Unknown  37.063722  -76.407042
# 13229             Unknown        NaN         NaN
# 13250                   6        NaN         NaN
# 13336             Unknown  41.879535  -87.624333
# 13342             Unknown        NaN         NaN
# 13355             Unknown        NaN         NaN
# 13367             Unknown        NaN         NaN
# 13371             Unknown        NaN         NaN
# 13409                   8  52.494307   13.434474
# 13421                   1  33.883700  -84.514400
# 13436                   2  13.764605  100.564220
# 13474             Unknown        NaN         NaN
# 13475             Unknown  33.806790 -118.146349
# 13476             Unknown        NaN         NaN
# 13510             Unknown        NaN         NaN
# 13552             Unknown  38.814208  -77.042423
# 13554                 107        NaN         NaN
# 13619                  40  33.141212 -117.320512
# 13713                  30  35.896906  -78.680678
#
#                                        oficina_principal  totalOffices
# 40     {'type': 'Point', 'coordinates': [-122.409173,...           1.0
# 46     {'type': 'Point', 'coordinates': [-122.067692,...           1.0
# 50     {'type': 'Point', 'coordinates': [-122.426804,...           1.0
# 54     {'type': 'Point', 'coordinates': [-122.07948, ...           3.0
# 78     {'type': 'Point', 'coordinates': [-122.137444,...           1.0
# 100                                                  NaN           4.0
# 103    {'type': 'Point', 'coordinates': [-122.206893,...           1.0
# 118    {'type': 'Point', 'coordinates': [2.350987, 48...           1.0
# 150                                                  NaN           1.0
# 189    {'type': 'Point', 'coordinates': [-71.051931, ...           3.0
# 205    {'type': 'Point', 'coordinates': [-122.399972,...           2.0
# 208    {'type': 'Point', 'coordinates': [-122.419204,...           1.0
# 209    {'type': 'Point', 'coordinates': [-122.402349,...           1.0
# 249    {'type': 'Point', 'coordinates': [-71.086596, ...           7.0
# 276    {'type': 'Point', 'coordinates': [-118.495566,...           1.0
# 301    {'type': 'Point', 'coordinates': [-118.243425,...           1.0
# 303    {'type': 'Point', 'coordinates': [-122.159928,...           1.0
# 323    {'type': 'Point', 'coordinates': [-122.39071, ...           4.0
# 332    {'type': 'Point', 'coordinates': [-122.401245,...           1.0
# 334    {'type': 'Point', 'coordinates': [-122.407959,...           1.0
# 342    {'type': 'Point', 'coordinates': [-79.948563, ...           1.0
# 343    {'type': 'Point', 'coordinates': [-73.98546, 4...           1.0
# 348                                                  NaN           1.0
# 350    {'type': 'Point', 'coordinates': [-73.971655, ...          10.0
# 379    {'type': 'Point', 'coordinates': [-122.392142,...           1.0
# 410    {'type': 'Point', 'coordinates': [-122.286493,...           1.0
# 433    {'type': 'Point', 'coordinates': [-71.058768, ...           1.0
# 460    {'type': 'Point', 'coordinates': [-73.997395, ...           1.0
# 464    {'type': 'Point', 'coordinates': [-118.49863, ...           1.0
# 486    {'type': 'Point', 'coordinates': [-74.001704, ...           2.0
# ...                                                  ...           ...
# 12974  {'type': 'Point', 'coordinates': [-118.4017053...           1.0
# 12989                                                NaN           1.0
# 13009                                                NaN           1.0
# 13015                                                NaN           1.0
# 13071  {'type': 'Point', 'coordinates': [-121.924053,...           1.0
# 13118  {'type': 'Point', 'coordinates': [-117.6686838...           1.0
# 13121  {'type': 'Point', 'coordinates': [-118.197677,...           1.0
# 13138  {'type': 'Point', 'coordinates': [-122.3451897...           1.0
# 13139  {'type': 'Point', 'coordinates': [-122.1861976...           1.0
# 13153  {'type': 'Point', 'coordinates': [-118.3794929...           1.0
# 13214                                                NaN           1.0
# 13215  {'type': 'Point', 'coordinates': [-76.407042, ...           1.0
# 13229                                                NaN           1.0
# 13250                                                NaN           1.0
# 13336  {'type': 'Point', 'coordinates': [-87.624333, ...           1.0
# 13342                                                NaN           1.0
# 13355                                                NaN           1.0
# 13367                                                NaN           1.0
# 13371                                                NaN           1.0
# 13409  {'type': 'Point', 'coordinates': [13.434474, 5...           1.0
# 13421  {'type': 'Point', 'coordinates': [-84.5144, 33...           1.0
# 13436  {'type': 'Point', 'coordinates': [100.5642201,...           1.0
# 13474                                                NaN           1.0
# 13475  {'type': 'Point', 'coordinates': [-118.1463485...           2.0
# 13476                                                NaN           1.0
# 13510                                                NaN           1.0
# 13552  {'type': 'Point', 'coordinates': [-77.042423, ...           1.0
# 13554                                                NaN           3.0
# 13619  {'type': 'Point', 'coordinates': [-117.3205123...           3.0
# 13713  {'type': 'Point', 'coordinates': [-78.6806784,...           1.0
#
# [592 rows x 9 columns]
